# %%
pip install verstack
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
missing_values = ["n/a", "na", "--","nan","Nan","NaN"]
df2 = pd.read_csv("titanic.csv", na_values=missing_values)
df2.head(10)
# Out:
#    pclass  survived                                            name     sex  \
# 0       1         1                    Allen Miss. Elisabeth Walton  female
# 1       1         1                   Allison Master. Hudson Trevor    male
# 2       1         0                     Allison Miss. Helen Loraine  female
# 3       1         0             Allison Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson Mr. Harry    male
# 6       1         1                Andrews Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews Mr. Thomas Jr    male
# 8       1         1    Appleton Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
df2.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home_dest     564
# dtype: int64

# %%
pip install --upgrade verstack
# Out:
# Requirement already up-to-date: verstack in c:\users\nageshreddy\anaconda3\lib\site-packages (0.4.4)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from verstack import NaNImputer

# %%
imputer = NaNImputer()

# %%
df_without_nans = imputer.impute(df2)
# Out:
# Dataset dimensions:
#  - rows:         1309
#  - columns:      14
#  - mb in memory: 0.14
#  - NaN cols num: 7
# --------------------------
# Changed (fixed) column boat to type float
# Incorrectly represented values replaced by np.nan
#
#
# Deploy multiprocessing with 8 parallel proceses
#
#
# NaNs imputation time: 0.22 minutes
# --------------------------------------------------

# %%
df_without_nans.head(10)
# Out:
#    pclass  survived                                            name     sex  \
# 0       1         1                    Allen Miss. Elisabeth Walton  female
# 1       1         1                   Allison Master. Hudson Trevor    male
# 2       1         0                     Allison Miss. Helen Loraine  female
# 3       1         0             Allison Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson Mr. Harry    male
# 6       1         1                Andrews Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews Mr. Thomas Jr    male
# 8       1         1    Appleton Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked  boat  \
# ...

# %%
df_without_nans.tail()
# Out:
#       pclass  survived                      name     sex        age  sibsp  \
# 1304       3         0       Zabour Miss. Hileni  female  14.500000      1
# 1305       3         0      Zabour Miss. Thamine  female  18.940481      1
# 1306       3         0  Zakarian Mr. Mapriededer    male  26.500000      0
# 1307       3         0        Zakarian Mr. Ortin    male  27.000000      0
# 1308       3         0         Zimmerman Mr. Leo    male  29.000000      0
#
#       parch  ticket     fare  cabin embarked  boat        body  \
# 1304      0    2665  14.4542     G6        C  15.0  328.000000
# 1305      0    2665  14.4542     G6        C  10.0  320.445099
# 1306      0    2656   7.2250  F G73        C  15.0  304.000000
# 1307      0    2670   7.2250  F G73        C  15.0  267.966003
# 1308      0  315082   7.8750     G6        S  15.0  192.976547
#
#                                home_dest
# 1304                         New York NY
# 1305                           Ottawa ON
# ...

# %%
df_without_nans.isna().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home_dest    0
# dtype: int64
