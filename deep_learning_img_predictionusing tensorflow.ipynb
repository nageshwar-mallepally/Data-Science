# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tn;

# %%
img = "F:\\photos\\photos\\bike.jpg"

# %%
#First method
from IPython.display import Image
Image(filename=img,width=224, height=224)

# %%
#Second method
from tensorflow.keras.preprocessing import image
img1 = image.load_img(img,target_size=(224,224))
import matplotlib.pyplot as plt
plt.imshow(img1)

# %%
#Third method
import cv2
imgg = cv2.imread(img)
plt.imshow(imgg)

# %%
img3 = cv2.resize(imgg, (225,225))
plt.imshow(img3)

# %%
#Forth method
from PIL import Image
im = Image.open(img)
im = im.resize((224,224))
plt.imshow(im)

# %%
mobile = tn.keras.applications.mobilenet_v2.MobileNetV2()

# %%
# creating model
# Training model
# Test model
# Predict model

# %%
#Pre-processing of Image

# %%
img = "F:\\photos\\photos\\download.jpeg"
#img = "F:\\photos\\photos\\DSC_1280.jpg"
#img = "F:\\photos\\photos\\DSC_9682.jpg"
from tensorflow.keras.preprocessing import image
img1 = image.load_img(img,target_size=(224,224))
plt.imshow(img1)
resize_img = image.img_to_array(img1)
resize_img.shape

import numpy as np
final_img = np.expand_dims(resize_img, axis=0)
final_img.shape
predictions = mobile.predict(final_img)
from tensorflow.keras.applications import imagenet_utils
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n04209239', 'shower_curtain', 0.8230082),
#   ('n03938244', 'pillow', 0.11053961),
#   ('n02834397', 'bib', 0.012572543),
#   ('n03485794', 'handkerchief', 0.0047736126),
#   ('n04507155', 'umbrella', 0.0025736117)]]

# %%
# Out:
# (224, 224, 3)

# %%
# Out:
# (1, 224, 224, 3)

# %%
res
# Out:
# [[('n04209239', 'shower_curtain', 0.98716426),
#   ('n03938244', 'pillow', 0.004137989),
#   ('n03485794', 'handkerchief', 0.000530923),
#   ('n02730930', 'apron', 0.00033520092),
#   ('n02910353', 'buckle', 0.000222023)]]
